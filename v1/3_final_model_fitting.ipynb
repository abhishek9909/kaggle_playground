# %%
import pickle
import glob

# %%
pickel_files = glob.glob("../data/rep/*.pkl")
pickel_files
# Out:
# ['../data/rep/vanilla_param_score_dict.pkl',
#  '../data/rep/optimized_param_score_dict.pkl']

# %%
with open(pickel_files[0], 'rb') as f:
    dict_1 = pickle.load(f)

print(dict_1.values())
# Out:
# dict_values([np.float64(0.28055274509803924), np.float64(0.2817176470588235), np.float64(0.2813662745098039), np.float64(0.27648784313725494), np.float64(0.2749713725490196), np.float64(0.2713509803921569), np.float64(0.27073647058823525), np.float64(0.28634313725490196), np.float64(0.27480450980392157), np.float64(0.2743027450980392)])

# %%
with open(pickel_files[1], 'rb') as f:
    dict_2 = pickle.load(f)

print(dict_2.values())
# Out:
# dict_values([np.float64(0.23879843137254902), np.float64(0.23879843137254902), np.float64(0.23879843137254902), np.float64(0.23879843137254902), np.float64(0.23879843137254902), np.float64(0.23879843137254902), np.float64(0.23879843137254902), np.float64(0.23879843137254902), np.float64(0.23879843137254902), np.float64(0.23879843137254902)])
